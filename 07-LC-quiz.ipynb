# %% [markdown]
# # Quiz

# %%
from IPython.display import display, Markdown

questions = [
    {
        "number": 1,
        "text": "Which of the following lists the main components of a modular framework for LLM application development, as described in the course?",
        "options": {
            "A": "The main components are APIs, prompts, templates, modules, orchestrators, evaluators, and caches.",
            "B": "The main components are models, prompts, transformers, datasets, pipelines, evaluators, and connectors.",
            "C": "The main components are models, encoders, decoders, datasets, scripts, agents, and visualizers.",
            "D": "The main components are models, prompts, parsers, indexes, chains, agents, and memory.",
        },
        "correct": "D",
        "explanation": "This set includes all of the key modular components discussed in the course for building LLM applications.",
    },
    {
        "number": 2,
        "text": "How do embeddings and vector stores work together to enable question answering over user-provided documents in LLM applications?",
        "options": {
            "A": "Embeddings convert text into vectors; vector stores index these for retrieval, enabling LLMs to answer questions over documents.",
            "B": "Embeddings translate text into different languages; vector stores store the translations, letting LLMs fetch responses in multiple languages.",
            "C": "Embeddings label documents by topic; vector stores group documents by label, helping LLMs select pre-written answers to questions.",
            "D": "Embeddings generate a single vector for each document; vector stores match queries to these document-level vectors, allowing LLMs to retrieve entire documents for answering.",
        },
        "correct": "A",
        "explanation": "Embeddings numerically represent chunks of text, which are stored in vector stores for efficient retrieval based on similarity to question embeddings.",
    },
    {
        "number": 3,
        "text": "Why are memory mechanisms necessary for maintaining conversational context in large language model applications?",
        "options": {
            "A": "Memory mechanisms are needed because large language models require additional storage to process complex queries from multiple users simultaneously.",
            "B": "Memory mechanisms are needed because large language models are stateless and cannot remember previous conversational turns without explicit context.",
            "C": "Memory mechanisms are needed because large language models rely on external databases to generate responses.",
        },
        "correct": "B",
        "explanation": "LLMs are stateless — each call is independent. Memory mechanisms explicitly pass prior conversation turns so the model can maintain context.",
    },
    {
        "number": 4,
        "text": "What is the primary role of prompts and output parsers when building applications with large language models (LLMs)?",
        "options": {
            "A": "Prompts organize LLM outputs; output parsers prepare input data so models can generate more accurate responses.",
            "B": "Prompts translate user questions for the LLM; output parsers grade the accuracy of the model's answers for evaluation.",
            "C": "Prompts determine the format of LLM responses; output parsers select which prompt templates to use for each input.",
            "D": "Prompts structure the LLM input; output parsers convert model outputs into structured formats usable for downstream tasks.",
        },
        "correct": "D",
        "explanation": "Prompts control what the model receives as input; output parsers process the raw text response into structured data (e.g. JSON, Python objects) that applications can use.",
    },
    {
        "number": 5,
        "text": "Which of the following best reflects how different types of chains are used to combine language models, prompts, and operations in LLM applications?",
        "options": {
            "A": "LLM chains, refinement chains, and evaluation chains combine language models, prompts, and different evaluation strategies for LLM tasks.",
            "B": "Router chains, retrieval chains, and embedding chains combine language models, prompts, and various retrieval or embedding operations in distinct workflows.",
            "C": "LLM chains, sequential chains, and router chains combine language models, prompts, and operations in different processing workflows.",
            "D": "Sequential chains, summarization chains, and transformation chains combine prompts, output parsers, and models for specific data processing pipelines.",
        },
        "correct": "C",
        "explanation": "LLM chains wrap a single model call, sequential chains pipe outputs through multiple steps, and router chains direct inputs to different sub-chains based on content.",
    },
    {
        "number": 6,
        "text": "What is the primary function of agents when enabling language models to interact with external tools or data sources for complex task completion?",
        "options": {
            "A": "Agents route tool interactions through predefined scripts to complete tasks.",
            "B": "Agents enable language models to decide when and how to use external tools or data sources to complete complex tasks.",
            "C": "Agents enable language models to decompose tasks into internal reasoning steps handled within the model's core logic.",
            "D": "Agents equip language models with preconstructed answer templates for complex tasks.",
        },
        "correct": "B",
        "explanation": "Agents give the LLM autonomy to choose which external tools to call and when, enabling dynamic multi-step task completion beyond the model's built-in knowledge.",
    },
    {
        "number": 7,
        "text": "What is a core challenge in evaluating LLM-based applications, and which methods are commonly used to address it?",
        "options": {
            "A": "Evaluating LLM applications is challenging due to open-ended outputs; solutions include manual review and using LLMs to generate and grade examples.",
            "B": "Evaluating LLM applications is challenging because of model latency; recommended methods include optimizing hardware and reducing model size for better performance.",
            "C": "Evaluating LLM applications is straightforward since outputs are predictable; most evaluations rely on automated string matching and keyword detection.",
            "D": "Evaluating LLM applications is difficult due to inconsistent input data; solutions focus on improving dataset quality and using statistical analysis tools.",
        },
        "correct": "A",
        "explanation": "LLM outputs are open-ended and varied, making exact matching insufficient. Using an LLM as a judge to grade predictions against reference answers is the standard scalable approach.",
    },
]

PASS_THRESHOLD = 5  # out of 7
score = 0

for q in questions:
    display(Markdown(f"---\n### Question {q['number']}\n\n**{q['text']}**"))
    for key, val in q["options"].items():
        display(Markdown(f"- **{key})** {val}"))

    answer = input(f"\nYour answer ({'/'.join(q['options'].keys())}): ").strip().upper()

    if answer == q["correct"]:
        display(Markdown(f"\u2705 **Correct!** {q['explanation']}"))
        score += 1
    else:
        display(Markdown(
            f"\u274c **Incorrect.** The correct answer is **{q['correct']}**: "
            f"{q['options'][q['correct']]}\n\n_{q['explanation']}_"
        ))

pct = score / len(questions) * 100
result = "\u2705 **Passed!**" if score >= PASS_THRESHOLD else "\u274c **Not passed.** Review the lessons and try again."
display(Markdown(
    f"---\n## Final Score: {score}/{len(questions)} ({pct:.0f}%)\n\n"
    f"Pass mark: {PASS_THRESHOLD}/{len(questions)} \u2014 {result}"
))
# Out:
# ---
# ### Question 1
#
# **Which of the following lists the main components of a modular framework for LLM application development, as described in the course?**
# - **A)** The main components are APIs, prompts, templates, modules, orchestrators, evaluators, and caches.
# - **B)** The main components are models, prompts, transformers, datasets, pipelines, evaluators, and connectors.
# - **C)** The main components are models, encoders, decoders, datasets, scripts, agents, and visualizers.
# - **D)** The main components are models, prompts, parsers, indexes, chains, agents, and memory.
# Your answer (A/B/C/D):  D
# ✅ **Correct!** This set includes all of the key modular components discussed in the course for building LLM applications.
# ---
# ### Question 2
#
# **How do embeddings and vector stores work together to enable question answering over user-provided documents in LLM applications?**
# ...
